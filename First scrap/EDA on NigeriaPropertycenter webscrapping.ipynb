# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Nigeria_housing.csv')
df = df.copy()
df.head()
# Out:
#                            Description  \
# 0  3 bedroom flat / apartment for rent
# 1  4 bedroom flat / apartment for rent
# 2  2 bedroom flat / apartment for rent
# 3  2 bedroom flat / apartment for rent
# 4                Office space for rent
#
#                                           House_type  \
# 0  3 Bedroom Flat With Additional Big Lounge, Swi...
# 1  Luxury 3 Bedroom Apartment & Bq That Comes Wit...
# 2  Well-spaced And Serviced With 24-hour Power Su...
# 3  Newly Built Luxury 2 Bedroom Apartment With Am...
# 4                      120sqm Open Plan Office Space
#
#                                             Location      Price
# 0    Mobolaji Johnson Street, Old Ikoyi, Ikoyi, L...  9,500,000
# 1                   Lekki Conservation, Lekki, Lagos  3,500,000
# 2                 Oniru, Victoria Island (VI), Lagos  6,500,000
# 3    Allied Gardens, Newly Built Apartment, Good ...  1,500,000
# 4                                Allen, Ikeja, Lagos     40,000

# %%
#Getting info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20979 entries, 0 to 20978
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Description  20979 non-null  object
#  1   House_type   20978 non-null  object
#  2   Location     20979 non-null  object
#  3   Price        20979 non-null  object
# dtypes: object(4)
# memory usage: 655.7+ KB

# %%
#Check number of missing data
df.isna().sum()
# Out:
# Description    0
# House_type     1
# Location       0
# Price          0
# dtype: int64

# %%
#Replacing special characters from the price column
df['Price'] = df['Price'].str.replace('[^\d\-+\.]', '', regex=True)

#changing dtype to numeric
df['Price'] = pd.to_numeric(df['Price'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20979 entries, 0 to 20978
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Description  20979 non-null  object
#  1   House_type   20978 non-null  object
#  2   Location     20979 non-null  object
#  3   Price        20979 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 655.7+ KB

# %%
#Getting state and address from location column
df[['Address', 'State']] = df['Location'].str.rsplit(',', n=1, expand=True)
df.head()
# Out:
#                            Description  \
# 0  3 bedroom flat / apartment for rent
# 1  4 bedroom flat / apartment for rent
# 2  2 bedroom flat / apartment for rent
# 3  2 bedroom flat / apartment for rent
# 4                Office space for rent
#
#                                           House_type  \
# 0  3 Bedroom Flat With Additional Big Lounge, Swi...
# 1  Luxury 3 Bedroom Apartment & Bq That Comes Wit...
# 2  Well-spaced And Serviced With 24-hour Power Su...
# 3  Newly Built Luxury 2 Bedroom Apartment With Am...
# 4                      120sqm Open Plan Office Space
#
#                                             Location    Price  \
# 0    Mobolaji Johnson Street, Old Ikoyi, Ikoyi, L...  9500000
# 1                   Lekki Conservation, Lekki, Lagos  3500000
# 2                 Oniru, Victoria Island (VI), Lagos  6500000
# 3    Allied Gardens, Newly Built Apartment, Good ...  1500000
# 4                                Allen, Ikeja, Lagos    40000
#
#                                              Address   State
# 0          Mobolaji Johnson Street, Old Ikoyi, Ikoyi   Lagos
# 1                          Lekki Conservation, Lekki   Lagos
# 2                        Oniru, Victoria Island (VI)   Lagos
# 3    Allied Gardens, Newly Built Apartment, Good ...   Lagos
# 4                                       Allen, Ikeja   Lagos

# %%
#Extracting city and street from address column
df[['street', 'city']] = df['Address'].str.rsplit(',', n=1, expand=True)
df.head()
# Out:
#                            Description  \
# 0  3 bedroom flat / apartment for rent
# 1  4 bedroom flat / apartment for rent
# 2  2 bedroom flat / apartment for rent
# 3  2 bedroom flat / apartment for rent
# 4                Office space for rent
#
#                                           House_type  \
# 0  3 Bedroom Flat With Additional Big Lounge, Swi...
# 1  Luxury 3 Bedroom Apartment & Bq That Comes Wit...
# 2  Well-spaced And Serviced With 24-hour Power Su...
# 3  Newly Built Luxury 2 Bedroom Apartment With Am...
# 4                      120sqm Open Plan Office Space
#
#                                             Location    Price  \
# 0    Mobolaji Johnson Street, Old Ikoyi, Ikoyi, L...  9500000
# 1                   Lekki Conservation, Lekki, Lagos  3500000
# 2                 Oniru, Victoria Island (VI), Lagos  6500000
# 3    Allied Gardens, Newly Built Apartment, Good ...  1500000
# 4                                Allen, Ikeja, Lagos    40000
#
#                                              Address   State  \
# 0          Mobolaji Johnson Street, Old Ikoyi, Ikoyi   Lagos
# 1                          Lekki Conservation, Lekki   Lagos
# 2                        Oniru, Victoria Island (VI)   Lagos
# 3    Allied Gardens, Newly Built Apartment, Good ...   Lagos
# 4                                       Allen, Ikeja   Lagos
#
#                                               street                   city
# 0                 Mobolaji Johnson Street, Old Ikoyi                  Ikoyi
# 1                                 Lekki Conservation                  Lekki
# 2                                              Oniru   Victoria Island (VI)
# 3    Allied Gardens, Newly Built Apartment, Good ...                   Ajah
# 4                                              Allen                  Ikeja

# %%
#Droping Location and address
df.drop(['Location', 'Address'], axis=1, inplace=True)
df.head()
# Out:
#                            Description  \
# 0  3 bedroom flat / apartment for rent
# 1  4 bedroom flat / apartment for rent
# 2  2 bedroom flat / apartment for rent
# 3  2 bedroom flat / apartment for rent
# 4                Office space for rent
#
#                                           House_type    Price   State  \
# 0  3 Bedroom Flat With Additional Big Lounge, Swi...  9500000   Lagos
# 1  Luxury 3 Bedroom Apartment & Bq That Comes Wit...  3500000   Lagos
# 2  Well-spaced And Serviced With 24-hour Power Su...  6500000   Lagos
# 3  Newly Built Luxury 2 Bedroom Apartment With Am...  1500000   Lagos
# 4                      120sqm Open Plan Office Space    40000   Lagos
#
#                                               street                   city
# 0                 Mobolaji Johnson Street, Old Ikoyi                  Ikoyi
# 1                                 Lekki Conservation                  Lekki
# 2                                              Oniru   Victoria Island (VI)
# 3    Allied Gardens, Newly Built Apartment, Good ...                   Ajah
# 4                                              Allen                  Ikeja

# %%
#To remove the special characters from city column
df['city'] = df['city'].str.replace(r'\W', '', regex=True)
df.head()
#To remove the special characters from State column
df['State'] = df['State'].str.replace(r'\W', '', regex=True)
df.head()
# Out:
#                            Description  \
# 0  3 bedroom flat / apartment for rent
# 1  4 bedroom flat / apartment for rent
# 2  2 bedroom flat / apartment for rent
# 3  2 bedroom flat / apartment for rent
# 4                Office space for rent
#
#                                           House_type    Price  State  \
# 0  3 Bedroom Flat With Additional Big Lounge, Swi...  9500000  Lagos
# 1  Luxury 3 Bedroom Apartment & Bq That Comes Wit...  3500000  Lagos
# 2  Well-spaced And Serviced With 24-hour Power Su...  6500000  Lagos
# 3  Newly Built Luxury 2 Bedroom Apartment With Am...  1500000  Lagos
# 4                      120sqm Open Plan Office Space    40000  Lagos
#
#                                               street              city
# 0                 Mobolaji Johnson Street, Old Ikoyi             Ikoyi
# 1                                 Lekki Conservation             Lekki
# 2                                              Oniru  VictoriaIslandVI
# 3    Allied Gardens, Newly Built Apartment, Good ...              Ajah
# 4                                              Allen             Ikeja

# %%
#Getting the unique cities
df['city'].unique()
# Out:
# array(['Ikoyi', 'Lekki', 'VictoriaIslandVI', 'Ajah', 'Ikeja',
#        'PortHarcourt', 'Gwarinpa', 'IbejuLekki', 'Katampe', None, 'Wuse2',
#        'Gbagada', 'LugbeDistrict', 'Jahi', 'AsokoroDistrict', 'Utako',
#        'Magodo', 'Yaba', 'Durumi', 'Apo', 'Ojodu', 'Wuse', 'Ikorodu',
#        'Mabushi', 'Kubwa', 'Isolo', 'GuzapeDistrict', 'LokogomaDistrict',
#        'Jabi', 'IduIndustrial', 'Kaura', 'Oshodi', 'AmuwoOdofin', 'Wuye',
#        'IsheriNorth', 'Enugu', 'Ogudu', 'Ipaja', 'IfakoIjaiye',
#        'Alimosho', 'Maryland', 'Ibadan', 'Surulere', 'Garki',
#        'Galadimawa', 'EkoAtlanticCity', 'MaitamaDistrict', 'Magboro',
#        'Karmo', 'Agege', 'Dutse', 'Ketu', 'LifeCamp', 'Gaduwa',
#        'MboraNbora', 'LagosIsland', 'Ijesha', 'Oredo', 'Shomolu',
#        'Dakibiyu', 'Arepo', 'Karsana', 'Zuba', 'Ilupeju', 'Gudu',
#        'Ikotun', 'Bwari', 'Apapa', 'ObafemiOwode', 'Isheri', 'Ojota',
#        'Mushin', 'IbadanNorth', 'AbeokutaSouth', 'Sagamu', 'WaruPozema',
#        'Akure', 'Dape', 'Epe', 'Ojo', 'Kado', 'MoweTown', 'Uyo', 'Ibeju',
#        'MoweOfada', 'AdoOdoOta', 'Ifo', 'Gwagwalada', 'Osogbo', 'Ibafo',
#        'Kosofe', 'Ayobo', 'AbeokutaNorth', 'Ijoko', 'Mpape', 'Badagry',
#        'Oluyole', 'CentralBusinessDistrict', 'OwerriWest', 'Suleja',
#        'IbadanSouthWest', 'Asaba', 'Umuahia', 'Ejigbo', 'Wumba',
#        'KadunaNorth', 'Uvwie', 'SangoOta', 'Onitsha', 'Eket',
#        'IlorinSouth', 'AgbaraIgbesa', 'KM46', 'IjebuEast', 'Ijede'],
#       dtype=object)

# %%
#number of cities
city = len(df['city'].unique())
city
# Out:
# 115

# %%
#number of houses
House = len(df['House_type'].unique())
House
# Out:
# 13807

# %%
#Getting the Average price of  houses in the each city
Avg = df.groupby('city').mean().astype(np.int64)
Avg
# Out:
#                   Price
# city
# AbeokutaNorth   3500000
# AbeokutaSouth    962500
# AdoOdoOta       2900000
# AgbaraIgbesa     150000
# Agege           3851740
# ...                 ...
# Wuse            5687320
# Wuse2           2307144
# Wuye           15775999
# Yaba            2413855
# Zuba             700000
#
# [114 rows x 1 columns]

# %%
#Most Popular House_type
df.groupby('House_type')['Description'].count().sort_values(ascending=False)
# Out:
# House_type
# 2 Bedroom Flat                                             193
# Ultra Luxury 4 Bedroom Apartment + 2 Bq+pool+gym+squash    157
# 3 Bedroom Flat                                             155
# 4 Bedroom Terrace Duplex                                   152
# Brand - New Single Room En-suite Within A Duplex           144
#                                                           ...
# Decent Mini Flat Upstairs                                    1
# Decent Mini Flat Upstairs With 2 Toilet And Bathroom         1
# Decent Mini Flat With 2 Toilets                              1
# Decent Mini Flat With Two Toilet /bath                       1
# Â 2 Bedroom Apartment                                        1
# Name: Description, Length: 13806, dtype: int64

# %%
#most popular house_type
house_typ = df['House_type'].value_counts()
Pop_house = house_typ.idxmax()
print(f'The most popular house type is: {Pop_house}')
# Out:
# The most popular house type is: 2 Bedroom Flat

# %% [markdown]
# # Average price for House_type

# %%
#Getting the Average price for house_type
House_type = df.groupby('House_type').mean().sort_values(by='Price',ascending=False).astype(np.int64)
House_type
# Out:
#                                                           Price
# House_type
# Topnotch 3 Bedroom Fully Serviced & Furnished T...  15000000000
# Spacious 3 Bedroom Apartments                        7000000000
# Spacious 5 Bedroom Semi Detached Duplex              5507500000
# A Luxuriously Finished 1 Bedroom Flat                3200000000
# Lovely 3 Bedroom Apartments                          2339500000
# ...                                                         ...
# Newly Built 498 Square Meter Office Space On 3r...          450
# 500 Sqm Grade A - Open Plan Serviced Office Spa...          450
# Fully Serviced 687sqm Office Space On The First...          250
# 687 Square Meters Letable Floor Space                       250
# Fully Serviced 687 Sqm Office Space On The Firs...          250
#
# [13806 rows x 1 columns]

# %% [markdown]
# # Average price for each state

# %%
#number of States
dfs = len(df['State'].unique())
dfs
# Out:
# 17

# %%
#Average price house for each state
state = df.groupby('State')['Price'].mean().sort_values(ascending=False).astype(np.int64)
state
# Out:
# State
# Abuja       15873069
# Lagos        9188502
# Ogun         7475936
# Enugu        4598181
# Rivers       4155660
# Oyo          2772885
# Anambra      2400000
# Ondo         2000000
# AkwaIbom     1605952
# Kaduna       1500000
# Delta        1348347
# Imo          1016666
# Niger        1000000
# Edo           626250
# Kwara         450000
# Abia          400000
# Osun          300000
# Name: Price, dtype: int64

# %%
plt.figure(figsize=(10,5))
state.plot(kind='bar', color='red')
plt.xlabel('Average House Price')
plt.title('Average House Price by State')
plt.show()

# %% [markdown]
# # State with the Max and Min Average price

# %%
#State and city with the Max and Min Average price
MxMn = df.groupby('State').max().sort_values(by='Price', ascending=False)
MxMn
# Out:
#                                               Description        Price  \
# State
# Abuja                                  Warehouse for rent  15000000000
# Lagos                                  Warehouse for rent  11000000000
# Ogun                                   Warehouse for rent    400000000
# Rivers                                 Warehouse for rent     90000000
# Oyo                                    Warehouse for rent     75000000
# Enugu                                  Warehouse for rent     25000000
# AkwaIbom                            Office space for rent      8000000
# Anambra           5 bedroom semi-detached duplex for rent      4000000
# Delta                               Office space for rent      3000000
# Imo                    4 bedroom detached duplex for rent      2000000
# Ondo                   5 bedroom detached duplex for rent      2000000
# Kaduna                              Office space for rent      1500000
# Edo                              4 bedroom house for rent      1200000
# Niger                 2 bedroom flat / apartment for rent      1000000
# Kwara                 3 bedroom flat / apartment for rent       450000
# Abia      1 bedroom mini flat (room and parlour) for rent       400000
# Osun                  3 bedroom flat / apartment for rent       300000
#
#                                                      street
# State
# Abuja                                  Zone E, Flomax Plaza
# Lagos                                    Zone C, Nicon Town
# Ogun                            Wendy Garuba Estate, Berger
# Rivers                                                 Woji
# Oyo                           University Of Ibadan, Ajibode
# Enugu                                       Thinkers Corner
# AkwaIbom                                        Uyeh Estate
# Anambra                        Commissioners Quarters, Awka
# Delta               Ulo By Commissioner Street With 33 Line
# Imo         Umuezeala Close To The Round About By The Si...
# Ondo                       Behind St Jacobs At Alagbaka Gra
# Kaduna                                     Yakubu Gowan Way
# Edo         Waec Rd, Off Ogunmwenyin Rd, Off Ugbor Centr...
# Niger                                          Apc Quarters
# Kwara       Behind 9ice Kids, Pipeline Road, F-division,...
# Abia                                 Ehimiri Housing Estate
# Osun                                             Agunbelewo

# %% [markdown]
# # For Houses in Lagos

# %%
#For Houses in Lagos
state_data = df[df['State'] == 'Lagos']
state_data.head()
# Out:
#                            Description  \
# 0  3 bedroom flat / apartment for rent
# 1  4 bedroom flat / apartment for rent
# 2  2 bedroom flat / apartment for rent
# 3  2 bedroom flat / apartment for rent
# 4                Office space for rent
#
#                                           House_type    Price  State  \
# 0  3 Bedroom Flat With Additional Big Lounge, Swi...  9500000  Lagos
# 1  Luxury 3 Bedroom Apartment & Bq That Comes Wit...  3500000  Lagos
# 2  Well-spaced And Serviced With 24-hour Power Su...  6500000  Lagos
# 3  Newly Built Luxury 2 Bedroom Apartment With Am...  1500000  Lagos
# 4                      120sqm Open Plan Office Space    40000  Lagos
#
#                                               street              city
# 0                 Mobolaji Johnson Street, Old Ikoyi             Ikoyi
# 1                                 Lekki Conservation             Lekki
# 2                                              Oniru  VictoriaIslandVI
# 3    Allied Gardens, Newly Built Apartment, Good ...              Ajah
# 4                                              Allen             Ikeja

# %%
# Group by city and calculate average price
grouped = state_data.groupby('city')['Price'].mean().sort_values(ascending=False)
grouped.head()
# Out:
# city
# Ojota      1.275000e+08
# Apapa      5.150994e+07
# Ilupeju    2.742500e+07
# Oshodi     2.741958e+07
# Ikoyi      2.471860e+07
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(15,8))
grouped.plot(kind='bar', color='red')
plt.xlabel('Average House Price')
plt.title('Average House Price by City in Lagos')
plt.show()

# %%
#Getting the houses in Lekki
df[df['city']=='Lekki']
# Out:
#                                Description  \
# 1      4 bedroom flat / apartment for rent
# 9                    Office space for rent
# 15     2 bedroom flat / apartment for rent
# 16      4 bedroom detached duplex for rent
# 19                           Shop for rent
# ...                                    ...
# 20969  2 bedroom flat / apartment for rent
# 20972  3 bedroom flat / apartment for rent
# 20974  2 bedroom flat / apartment for rent
# 20975  3 bedroom flat / apartment for rent
# 20976  3 bedroom flat / apartment for rent
#
#                                               House_type     Price  State  \
# 1      Luxury 3 Bedroom Apartment & Bq That Comes Wit...   3500000  Lagos
# 9                                     4br Duplex With Bq   8000000  Lagos
# 15          Furnished Two Bedroom Flat With Bq Available   8500000  Lagos
# 16     5 Bedroom Fully Detached Duplex With Bq And Sw...  11000000  Lagos
# 19                                     25 Sqm Shop Space   3500000  Lagos
# ...                                                  ...       ...    ...
# 20969               Luxury Brand New 2 Bedroom Apartment   5000000  Lagos
# 20972  Newly Built Fully Serviced 3 Bedroom Apartment...   5000000  Lagos
# 20974                Fully Furnished 2 Bedroom Apartment   5000000  Lagos
# 20975          Serviced And Spacious 3 Bedroom Apartment   5000000  Lagos
# 20976    Fully Serviced 3 Bedroom Ground Floor Apartment   4500000  Lagos
#
#                                                   street   city
# 1                                     Lekki Conservation  Lekki
# 9        Oye Balogun Street, Lekki Phase 1, Lekki Pha...  Lekki
# 15                                                   V I  Lekki
# 16                                          Osapa London  Lekki
# 19                                         Lekki Phase 1  Lekki
# ...                                                  ...    ...
# 20969                           Admiralty, Lekki Phase 1  Lekki
# 20972                          Providence, Lekki Phase 1  Lekki
# 20974                                            Chevron  Lekki
# 20975                            Cromwell Estate Chevron  Lekki
# 20976                          Providence, Lekki Phase 1  Lekki
#
# [7934 rows x 6 columns]

# %%
#Getting the price of Houses in Lekki
dfc = df.groupby('city').get_group('Lekki')['Price']
print(dfc)
# Out:
# 1         3500000
# 9         8000000
# 15        8500000
# 16       11000000
# 19        3500000
#            ...
# 20969     5000000
# 20972     5000000
# 20974     5000000
# 20975     5000000
# 20976     4500000
# Name: Price, Length: 7934, dtype: int64

# %% [markdown]
# # Getting price of houses of in porthartcourt

# %%
#Getting price of houses of in porthartcourt
Rivers = df[df['State']== 'Rivers']
Rivers
# Out:
#                                    Description  \
# 8           4 bedroom detached duplex for rent
# 13                       Office space for rent
# 223        2 bedroom flat / apartment for rent
# 224    28 bedroom hotel / guest house for rent
# 225    4 bedroom semi-detached duplex for rent
# ...                                        ...
# 20731      2 bedroom flat / apartment for rent
# 20732      3 bedroom flat / apartment for rent
# 20757      2 bedroom flat / apartment for rent
# 20859       5 bedroom detached duplex for rent
# 20861      4 bedroom flat / apartment for rent
#
#                                               House_type     Price   State  \
# 8      Elegantly Furnished 4 Bedrooms Duplex With Bq ...   8000000  Rivers
# 13               Ultra Modern Office Complex On 4 Floors     50000  Rivers
# 223    Serviced & Fully Furnished 2 Bedroom Flat With...   3500000  Rivers
# 224                                          Mini Estate  40000000  Rivers
# 225          Fully Furnished & Services 4 Bedroom Duplex   7500000  Rivers
# ...                                                  ...       ...     ...
# 20731            Newly Built Pop Standard 2 Bedroom Flat   1700000  Rivers
# 20732  Spanish Standard 3 Bedroom Duplex In A Gated E...   2500000  Rivers
# 20757               Standard 2 Bedroom With Steady Light    400000  Rivers
# 20859  A Five (5) Bedroom Detached House With Service...  10000000  Rivers
# 20861           A Serviced 3 Bedroom Luxury Flat With Bq   4500000  Rivers
#
#                                                   street          city
# 8         Golf Estate, Off Peter Odili Road, Trans Amadi  PortHarcourt
# 13                                           GRA Phase 2  PortHarcourt
# 223                         Off Abacha Road, GRA Phase 3  PortHarcourt
# 224                     Off Nzimiro Amadi Flats, Old GRA  PortHarcourt
# 225                     Golf Estate Off Peter Odili Road  PortHarcourt
# ...                                                  ...           ...
# 20731    Shell Cooperative Estate Off G U Akeh Road E...  PortHarcourt
# 20732    Alfredo Avenue Off Parkland Estate Odili Roa...  PortHarcourt
# 20757                                          Rumuodara  PortHarcourt
# 20859                                            Old GRA  PortHarcourt
# 20861                                      Port Harcourt          None
#
# [250 rows x 6 columns]

# %%
PH = Rivers.groupby('city')['Price'].mean().sort_values(ascending=False)
PH
# Out:
# city
# PortHarcourt    4.162964e+06
# Name: Price, dtype: float64

# %%
#Getting average price of house in PortHarcourt
df[df['city']== 'PortHarcourt'].mean().astype(np.int64)
#df.groupby('city').get_group('PortHarcourt')['Price'].mean().astype(np.int64)
# Out:
# Price    4162963
# dtype: int64

# %%
df.head()
# Out:
#                            Description  \
# 0  3 bedroom flat / apartment for rent
# 1  4 bedroom flat / apartment for rent
# 2  2 bedroom flat / apartment for rent
# 3  2 bedroom flat / apartment for rent
# 4                Office space for rent
#
#                                           House_type    Price  State  \
# 0  3 Bedroom Flat With Additional Big Lounge, Swi...  9500000  Lagos
# 1  Luxury 3 Bedroom Apartment & Bq That Comes Wit...  3500000  Lagos
# 2  Well-spaced And Serviced With 24-hour Power Su...  6500000  Lagos
# 3  Newly Built Luxury 2 Bedroom Apartment With Am...  1500000  Lagos
# 4                      120sqm Open Plan Office Space    40000  Lagos
#
#                                               street              city
# 0                 Mobolaji Johnson Street, Old Ikoyi             Ikoyi
# 1                                 Lekki Conservation             Lekki
# 2                                              Oniru  VictoriaIslandVI
# 3    Allied Gardens, Newly Built Apartment, Good ...              Ajah
# 4                                              Allen             Ikeja

# %%
# fill missing values with the mean
df['Price'] = df['Price'].fillna(df['Price'].mean())

# %%
df
# Out:
#                                Description  \
# 0      3 bedroom flat / apartment for rent
# 1      4 bedroom flat / apartment for rent
# 2      2 bedroom flat / apartment for rent
# 3      2 bedroom flat / apartment for rent
# 4                    Office space for rent
# ...                                    ...
# 20974  2 bedroom flat / apartment for rent
# 20975  3 bedroom flat / apartment for rent
# 20976  3 bedroom flat / apartment for rent
# 20977  2 bedroom flat / apartment for rent
# 20978  2 bedroom flat / apartment for rent
#
#                                               House_type    Price  State  \
# 0      3 Bedroom Flat With Additional Big Lounge, Swi...  9500000  Lagos
# 1      Luxury 3 Bedroom Apartment & Bq That Comes Wit...  3500000  Lagos
# 2      Well-spaced And Serviced With 24-hour Power Su...  6500000  Lagos
# 3      Newly Built Luxury 2 Bedroom Apartment With Am...  1500000  Lagos
# 4                          120sqm Open Plan Office Space    40000  Lagos
# ...                                                  ...      ...    ...
# 20974                Fully Furnished 2 Bedroom Apartment  5000000  Lagos
# 20975          Serviced And Spacious 3 Bedroom Apartment  5000000  Lagos
# 20976    Fully Serviced 3 Bedroom Ground Floor Apartment  4500000  Lagos
# 20977  Spacious And Lovely 2 Bedroom Flat, Parking Sp...   250000  Lagos
# 20978  Newly Built Massive ,spacious And Lovely 2 Bed...   300000  Lagos
#
#                                                   street              city
# 0                     Mobolaji Johnson Street, Old Ikoyi             Ikoyi
# 1                                     Lekki Conservation             Lekki
# 2                                                  Oniru  VictoriaIslandVI
# 3        Allied Gardens, Newly Built Apartment, Good ...              Ajah
# 4                                                  Allen             Ikeja
# ...                                                  ...               ...
# 20974                                            Chevron             Lekki
# 20975                            Cromwell Estate Chevron             Lekki
# 20976                          Providence, Lekki Phase 1             Lekki
# 20977                              Ile Omi Ijede Ikorodu             Ijede
# 20978                              Abuleko Ijede Ikorodu             Ijede
#
# [20979 rows x 6 columns]

# %%
dfR = df.corr()
dfR
# Out:
#        Price
# Price    1.0

# %%
# Creating a heatmap
plt.figure(figsize=(10,10))
sns.heatmap(dfR, annot=True, cmap='coolwarm')

# Display the heatmap
plt.show()
